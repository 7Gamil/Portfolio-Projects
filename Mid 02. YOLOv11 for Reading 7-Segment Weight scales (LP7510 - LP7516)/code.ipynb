# %% [markdown]
# # Please use one of the following methods for inference with the model.
#
# #### 1. Predict video
# #### 2. Predict image
# #### 3. Live camera

# %% [markdown]
# # Before starting, modify your Ultralytics library to handle grayscale images (see the README.md file).

# %% [markdown]
# # 1. Predict video

# %%
from ultralytics import YOLO
import cv2
import torch

# Load the YOLO model
model = YOLO("Model/yolo11s_30k_images_64_epochs_grayscale_only.pt")
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')  # Use GPU if available
model = model.to(device)

# Video path
video_path = "Data/test/test5fps.mp4"  # Replace with your video path

# Open the video file
cap = cv2.VideoCapture(video_path)

# Check if video opened successfully
if not cap.isOpened():
    print("Error opening video file")
    exit()

# Get video properties (optional)
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = cap.get(cv2.CAP_PROP_FPS)
fourcc = cv2.VideoWriter_fourcc(*'mp4v') # Codec for output video

out = cv2.VideoWriter('result_video_1.mp4', fourcc, fps, (width, height)) # Output video writer

while(cap.isOpened()):
    ret, frame = cap.read()
    if ret:
        # Perform inference on the frame
        frame_gray = cv2.cvtColor(frame, cv2.COLOR_RGB2GRAY)
        results = model(frame_gray, ch=1)

        # Annotate the frame with bounding boxes and labels
        annotated_frame = results[0].plot(img=frame) #Plot a single result on the frame

        for i, result in enumerate(results):
            boxes = result.boxes
            sorted_boxes = sorted(
                boxes,
                key=lambda b: b.xyxy[0][0].item()
            )
           
            digits_in_frame = []
            for box in sorted_boxes:
                class_idx = int(box.cls[0].item())
                class_name = result.names[class_idx]
                digits_in_frame.append(class_name)

            text_result = ''.join(digits_in_frame)

        position = (10, 100) 
        font = cv2.FONT_HERSHEY_DUPLEX
        font_scale = 3
        thickness = 3

        annotated_frame = cv2.putText(annotated_frame, text_result, position, font, font_scale, (0, 255, 0), thickness)


        # Display the annotated frame
        #cv2.imshow('YOLO Video', annotated_frame)
        out.write(annotated_frame)

        # Press 'q' to exit
        #if cv2.waitKey(1) & 0xFF == ord('q'):
            #break
    else:
        break

# Release the video capture and writer objects
cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# 0: 544x640 (no detections), 5.5ms
# Speed: 0.5ms preprocess, 5.5ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.6ms
# Speed: 0.6ms preprocess, 5.6ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 7.0ms
# Speed: 0.5ms preprocess, 7.0ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.4ms
# Speed: 0.6ms preprocess, 5.4ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.3ms
# Speed: 0.5ms preprocess, 5.3ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.8ms
# Speed: 0.6ms preprocess, 6.8ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.2ms
# Speed: 0.9ms preprocess, 6.2ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.7ms
# Speed: 0.6ms preprocess, 5.7ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.4ms
# Speed: 0.6ms preprocess, 5.4ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.8ms
# Speed: 0.6ms preprocess, 5.8ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.9ms
# Speed: 1.1ms preprocess, 5.9ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.7ms
# Speed: 0.6ms preprocess, 5.7ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.6ms
# Speed: 0.6ms preprocess, 5.6ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 13.0ms
# Speed: 0.6ms preprocess, 13.0ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.6ms
# Speed: 0.5ms preprocess, 5.6ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 8.6ms
# Speed: 0.9ms preprocess, 8.6ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.4ms
# Speed: 0.5ms preprocess, 6.4ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 9.1ms
# Speed: 0.6ms preprocess, 9.1ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.1ms
# Speed: 0.6ms preprocess, 6.1ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.6ms
# Speed: 0.6ms preprocess, 6.6ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.0ms
# Speed: 0.6ms preprocess, 6.0ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.2ms
# Speed: 0.6ms preprocess, 6.2ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.1ms
# Speed: 0.7ms preprocess, 6.1ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.3ms
# Speed: 0.6ms preprocess, 6.3ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.5ms
# Speed: 0.8ms preprocess, 5.5ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 7.1ms
# Speed: 0.6ms preprocess, 7.1ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.3ms
# Speed: 0.6ms preprocess, 5.3ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.8ms
# Speed: 0.6ms preprocess, 6.8ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 7.0ms
# Speed: 0.6ms preprocess, 7.0ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.7ms
# Speed: 0.5ms preprocess, 6.7ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.3ms
# Speed: 0.6ms preprocess, 6.3ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.6ms
# Speed: 0.5ms preprocess, 5.6ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.9ms
# Speed: 0.6ms preprocess, 5.9ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.7ms
# Speed: 0.6ms preprocess, 6.7ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.1ms
# Speed: 0.7ms preprocess, 6.1ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.5ms
# Speed: 0.6ms preprocess, 5.5ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.4ms
# Speed: 0.6ms preprocess, 5.4ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 19.8ms
# Speed: 0.8ms preprocess, 19.8ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.9ms
# Speed: 1.1ms preprocess, 6.9ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.2ms
# Speed: 0.6ms preprocess, 6.2ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.2ms
# Speed: 0.5ms preprocess, 5.2ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.4ms
# Speed: 0.5ms preprocess, 5.4ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.9ms
# Speed: 0.6ms preprocess, 5.9ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.6ms
# Speed: 0.6ms preprocess, 5.6ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.0ms
# Speed: 0.6ms preprocess, 6.0ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 10.1ms
# Speed: 1.2ms preprocess, 10.1ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.3ms
# Speed: 0.9ms preprocess, 5.3ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 12.0ms
# Speed: 0.5ms preprocess, 12.0ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.3ms
# Speed: 0.6ms preprocess, 6.3ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 11.5ms
# Speed: 0.5ms preprocess, 11.5ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.3ms
# Speed: 0.5ms preprocess, 6.3ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 7.6ms
# Speed: 0.6ms preprocess, 7.6ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.8ms
# Speed: 0.5ms preprocess, 6.8ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.4ms
# Speed: 0.6ms preprocess, 5.4ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.9ms
# Speed: 0.5ms preprocess, 5.9ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 8.8ms
# Speed: 0.6ms preprocess, 8.8ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.4ms
# Speed: 0.5ms preprocess, 6.4ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 7.2ms
# Speed: 0.7ms preprocess, 7.2ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.3ms
# Speed: 0.5ms preprocess, 5.3ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.7ms
# Speed: 0.5ms preprocess, 5.7ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.4ms
# Speed: 0.6ms preprocess, 6.4ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.9ms
# Speed: 0.5ms preprocess, 5.9ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.5ms
# Speed: 0.6ms preprocess, 6.5ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 8.6ms
# Speed: 0.7ms preprocess, 8.6ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.2ms
# Speed: 0.6ms preprocess, 6.2ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.4ms
# Speed: 0.6ms preprocess, 5.4ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.9ms
# Speed: 0.6ms preprocess, 5.9ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 10.6ms
# Speed: 0.9ms preprocess, 10.6ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.0ms
# Speed: 0.6ms preprocess, 6.0ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 8.0ms
# Speed: 0.5ms preprocess, 8.0ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.8ms
# Speed: 0.6ms preprocess, 5.8ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 9.1ms
# Speed: 0.8ms preprocess, 9.1ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 7.4ms
# Speed: 0.7ms preprocess, 7.4ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.6ms
# Speed: 0.5ms preprocess, 5.6ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.7ms
# Speed: 0.7ms preprocess, 5.7ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.4ms
# Speed: 0.5ms preprocess, 6.4ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.7ms
# Speed: 0.6ms preprocess, 6.7ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 8.3ms
# Speed: 0.7ms preprocess, 8.3ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.0ms
# Speed: 0.5ms preprocess, 6.0ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.0ms
# Speed: 0.8ms preprocess, 6.0ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 8.1ms
# Speed: 0.5ms preprocess, 8.1ms inference, 1.2ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 7.5ms
# Speed: 0.7ms preprocess, 7.5ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 10.3ms
# Speed: 0.6ms preprocess, 10.3ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.6ms
# Speed: 0.8ms preprocess, 5.6ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.4ms
# Speed: 0.6ms preprocess, 5.4ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.5ms
# Speed: 0.7ms preprocess, 6.5ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.6ms
# Speed: 0.6ms preprocess, 6.6ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.7ms
# Speed: 0.6ms preprocess, 6.7ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.8ms
# Speed: 0.5ms preprocess, 5.8ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 7.0ms
# Speed: 0.6ms preprocess, 7.0ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.7ms
# Speed: 0.7ms preprocess, 5.7ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.6ms
# Speed: 0.5ms preprocess, 5.6ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.0ms
# Speed: 0.6ms preprocess, 6.0ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.6ms
# Speed: 0.6ms preprocess, 6.6ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 10.0ms
# Speed: 0.7ms preprocess, 10.0ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.6ms
# Speed: 0.9ms preprocess, 6.6ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 8.1ms
# Speed: 1.2ms preprocess, 8.1ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 8.2ms
# Speed: 1.1ms preprocess, 8.2ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 7.7ms
# Speed: 0.7ms preprocess, 7.7ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 7.9ms
# Speed: 0.7ms preprocess, 7.9ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 8.5ms
# Speed: 0.6ms preprocess, 8.5ms inference, 0.8ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.5ms
# Speed: 0.7ms preprocess, 6.5ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 10.6ms
# Speed: 0.7ms preprocess, 10.6ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 13.2ms
# Speed: 0.9ms preprocess, 13.2ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.3ms
# Speed: 0.6ms preprocess, 6.3ms inference, 0.8ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 7.7ms
# Speed: 0.6ms preprocess, 7.7ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.2ms
# Speed: 0.6ms preprocess, 6.2ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.1ms
# Speed: 0.7ms preprocess, 6.1ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.9ms
# Speed: 0.6ms preprocess, 5.9ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 14.0ms
# Speed: 0.8ms preprocess, 14.0ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 8.1ms
# Speed: 0.9ms preprocess, 8.1ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 15.5ms
# Speed: 0.8ms preprocess, 15.5ms inference, 1.1ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 7.5ms
# Speed: 0.6ms preprocess, 7.5ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 4.9ms
# Speed: 0.7ms preprocess, 4.9ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.5ms
# Speed: 0.7ms preprocess, 6.5ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.3ms
# Speed: 0.6ms preprocess, 5.3ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.6ms
# Speed: 0.7ms preprocess, 5.6ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.9ms
# Speed: 1.1ms preprocess, 5.9ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.7ms
# Speed: 0.6ms preprocess, 6.7ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.9ms
# Speed: 0.9ms preprocess, 6.9ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.5ms
# Speed: 0.6ms preprocess, 5.5ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.0ms
# Speed: 0.6ms preprocess, 6.0ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.8ms
# Speed: 0.6ms preprocess, 5.8ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.4ms
# Speed: 0.8ms preprocess, 6.4ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 8.9ms
# Speed: 0.6ms preprocess, 8.9ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 7.1ms
# Speed: 0.6ms preprocess, 7.1ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 7.5ms
# Speed: 0.6ms preprocess, 7.5ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 9.3ms
# Speed: 0.6ms preprocess, 9.3ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.9ms
# Speed: 0.7ms preprocess, 6.9ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.3ms
# Speed: 0.5ms preprocess, 6.3ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 8.7ms
# Speed: 0.6ms preprocess, 8.7ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.1ms
# Speed: 0.6ms preprocess, 6.1ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.0ms
# Speed: 0.6ms preprocess, 6.0ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.1ms
# Speed: 1.1ms preprocess, 6.1ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.5ms
# Speed: 0.9ms preprocess, 5.5ms inference, 1.3ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 9.0ms
# Speed: 0.7ms preprocess, 9.0ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.2ms
# Speed: 0.6ms preprocess, 6.2ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.5ms
# Speed: 0.6ms preprocess, 6.5ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 7.4ms
# Speed: 1.0ms preprocess, 7.4ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 7.6ms
# Speed: 1.0ms preprocess, 7.6ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.4ms
# Speed: 0.6ms preprocess, 5.4ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.8ms
# Speed: 0.6ms preprocess, 5.8ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.6ms
# Speed: 0.7ms preprocess, 5.6ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 7.7ms
# Speed: 0.6ms preprocess, 7.7ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.0ms
# Speed: 0.7ms preprocess, 6.0ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.5ms
# Speed: 0.6ms preprocess, 6.5ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.5ms
# Speed: 0.8ms preprocess, 5.5ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.9ms
# Speed: 0.9ms preprocess, 5.9ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.8ms
# Speed: 1.3ms preprocess, 6.8ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 8.7ms
# Speed: 1.3ms preprocess, 8.7ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.1ms
# Speed: 0.7ms preprocess, 6.1ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.1ms
# Speed: 0.5ms preprocess, 6.1ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.2ms
# Speed: 0.6ms preprocess, 5.2ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.5ms
# Speed: 0.6ms preprocess, 5.5ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.6ms
# Speed: 0.6ms preprocess, 5.6ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.8ms
# Speed: 0.9ms preprocess, 6.8ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 9.3ms
# Speed: 0.8ms preprocess, 9.3ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.8ms
# Speed: 0.7ms preprocess, 5.8ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.2ms
# Speed: 0.8ms preprocess, 5.2ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.7ms
# Speed: 0.6ms preprocess, 5.7ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 7.9ms
# Speed: 0.7ms preprocess, 7.9ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.4ms
# Speed: 0.7ms preprocess, 6.4ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 9.9ms
# Speed: 0.7ms preprocess, 9.9ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.3ms
# Speed: 0.7ms preprocess, 6.3ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 9.0ms
# Speed: 0.6ms preprocess, 9.0ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.5ms
# Speed: 0.6ms preprocess, 5.5ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.4ms
# Speed: 0.6ms preprocess, 6.4ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.1ms
# Speed: 0.6ms preprocess, 6.1ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 18.1ms
# Speed: 1.8ms preprocess, 18.1ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 11.9ms
# Speed: 0.7ms preprocess, 11.9ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.2ms
# Speed: 1.0ms preprocess, 6.2ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.1ms
# Speed: 1.5ms preprocess, 6.1ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.4ms
# Speed: 0.6ms preprocess, 5.4ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.3ms
# Speed: 0.5ms preprocess, 5.3ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 11.3ms
# Speed: 0.6ms preprocess, 11.3ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.0ms
# Speed: 0.6ms preprocess, 6.0ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 13.2ms
# Speed: 0.7ms preprocess, 13.2ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.4ms
# Speed: 0.7ms preprocess, 5.4ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.3ms
# Speed: 0.6ms preprocess, 5.3ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.0ms
# Speed: 0.5ms preprocess, 6.0ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 5.3ms
# Speed: 0.6ms preprocess, 5.3ms inference, 1.1ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 5.8ms
# Speed: 0.6ms preprocess, 5.8ms inference, 1.1ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.1ms
# Speed: 0.6ms preprocess, 6.1ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.8ms
# Speed: 0.6ms preprocess, 5.8ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.4ms
# Speed: 0.7ms preprocess, 5.4ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.9ms
# Speed: 0.6ms preprocess, 5.9ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.2ms
# Speed: 0.7ms preprocess, 6.2ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.0ms
# Speed: 0.8ms preprocess, 6.0ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.4ms
# Speed: 0.6ms preprocess, 5.4ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.3ms
# Speed: 0.6ms preprocess, 5.3ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.6ms
# Speed: 0.7ms preprocess, 6.6ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.9ms
# Speed: 0.6ms preprocess, 6.9ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.8ms
# Speed: 0.6ms preprocess, 5.8ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.8ms
# Speed: 0.6ms preprocess, 5.8ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.7ms
# Speed: 0.6ms preprocess, 5.7ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.6ms
# Speed: 0.6ms preprocess, 5.6ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.1ms
# Speed: 0.6ms preprocess, 6.1ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 7.1ms
# Speed: 0.6ms preprocess, 7.1ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.7ms
# Speed: 0.6ms preprocess, 6.7ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.9ms
# Speed: 0.6ms preprocess, 6.9ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.9ms
# Speed: 1.0ms preprocess, 6.9ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.6ms
# Speed: 0.6ms preprocess, 6.6ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.6ms
# Speed: 0.6ms preprocess, 6.6ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.3ms
# Speed: 0.7ms preprocess, 6.3ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.6ms
# Speed: 0.7ms preprocess, 6.6ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 7.3ms
# Speed: 0.7ms preprocess, 7.3ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.9ms
# Speed: 0.7ms preprocess, 6.9ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.7ms
# Speed: 0.6ms preprocess, 5.7ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 7.1ms
# Speed: 0.9ms preprocess, 7.1ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.7ms
# Speed: 0.6ms preprocess, 5.7ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.9ms
# Speed: 0.6ms preprocess, 5.9ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.6ms
# Speed: 1.0ms preprocess, 5.6ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.8ms
# Speed: 0.6ms preprocess, 5.8ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.7ms
# Speed: 0.6ms preprocess, 5.7ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.3ms
# Speed: 0.6ms preprocess, 5.3ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.9ms
# Speed: 0.7ms preprocess, 5.9ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.2ms
# Speed: 0.6ms preprocess, 6.2ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.8ms
# Speed: 0.6ms preprocess, 5.8ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.1ms
# Speed: 0.7ms preprocess, 6.1ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.7ms
# Speed: 0.6ms preprocess, 5.7ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.7ms
# Speed: 0.6ms preprocess, 5.7ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.5ms
# Speed: 0.9ms preprocess, 5.5ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.9ms
# Speed: 0.6ms preprocess, 5.9ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.0ms
# Speed: 0.9ms preprocess, 6.0ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 9.9ms
# Speed: 0.7ms preprocess, 9.9ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.6ms
# Speed: 0.6ms preprocess, 6.6ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.7ms
# Speed: 0.6ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.3ms
# Speed: 0.6ms preprocess, 5.3ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.8ms
# Speed: 0.6ms preprocess, 5.8ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.4ms
# Speed: 0.7ms preprocess, 5.4ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.1ms
# Speed: 0.6ms preprocess, 6.1ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.7ms
# Speed: 0.7ms preprocess, 6.7ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.8ms
# Speed: 0.6ms preprocess, 6.8ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.3ms
# Speed: 0.6ms preprocess, 5.3ms inference, 1.1ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 15.2ms
# Speed: 0.7ms preprocess, 15.2ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 8.0ms
# Speed: 1.1ms preprocess, 8.0ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.6ms
# Speed: 0.6ms preprocess, 5.6ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.7ms
# Speed: 0.8ms preprocess, 5.7ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.0ms
# Speed: 0.6ms preprocess, 6.0ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.7ms
# Speed: 0.6ms preprocess, 5.7ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.0ms
# Speed: 0.6ms preprocess, 6.0ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.0ms
# Speed: 0.7ms preprocess, 6.0ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.8ms
# Speed: 0.7ms preprocess, 5.8ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.4ms
# Speed: 0.6ms preprocess, 5.4ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 11.1ms
# Speed: 0.6ms preprocess, 11.1ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.2ms
# Speed: 0.9ms preprocess, 6.2ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.8ms
# Speed: 0.8ms preprocess, 5.8ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.4ms
# Speed: 0.6ms preprocess, 6.4ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.0ms
# Speed: 0.6ms preprocess, 6.0ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.3ms
# Speed: 0.6ms preprocess, 6.3ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 7.2ms
# Speed: 0.6ms preprocess, 7.2ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.6ms
# Speed: 0.6ms preprocess, 6.6ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.1ms
# Speed: 0.7ms preprocess, 5.1ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.6ms
# Speed: 0.7ms preprocess, 5.6ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 9.6ms
# Speed: 0.8ms preprocess, 9.6ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.0ms
# Speed: 0.7ms preprocess, 6.0ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.5ms
# Speed: 0.7ms preprocess, 5.5ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.7ms
# Speed: 0.6ms preprocess, 6.7ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 8.6ms
# Speed: 0.6ms preprocess, 8.6ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.8ms
# Speed: 0.8ms preprocess, 6.8ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.6ms
# Speed: 0.6ms preprocess, 5.6ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.5ms
# Speed: 0.6ms preprocess, 5.5ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.7ms
# Speed: 0.6ms preprocess, 5.7ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.5ms
# Speed: 0.6ms preprocess, 5.5ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.9ms
# Speed: 0.9ms preprocess, 6.9ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.0ms
# Speed: 0.6ms preprocess, 6.0ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.4ms
# Speed: 0.8ms preprocess, 5.4ms inference, 0.8ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.5ms
# Speed: 0.6ms preprocess, 5.5ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.4ms
# Speed: 0.6ms preprocess, 5.4ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.5ms
# Speed: 0.6ms preprocess, 5.5ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.3ms
# Speed: 0.6ms preprocess, 5.3ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.4ms
# Speed: 0.6ms preprocess, 5.4ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.7ms
# Speed: 0.8ms preprocess, 6.7ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.1ms
# Speed: 0.6ms preprocess, 6.1ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.7ms
# Speed: 0.6ms preprocess, 5.7ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.7ms
# Speed: 0.6ms preprocess, 5.7ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.9ms
# Speed: 0.7ms preprocess, 5.9ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.1ms
# Speed: 0.7ms preprocess, 6.1ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 7.0ms
# Speed: 0.7ms preprocess, 7.0ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.0ms
# Speed: 0.6ms preprocess, 6.0ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.1ms
# Speed: 0.6ms preprocess, 6.1ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 10.3ms
# Speed: 1.2ms preprocess, 10.3ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 11.0ms
# Speed: 1.4ms preprocess, 11.0ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.4ms
# Speed: 0.6ms preprocess, 6.4ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.7ms
# Speed: 0.6ms preprocess, 5.7ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.9ms
# Speed: 0.6ms preprocess, 5.9ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.7ms
# Speed: 0.6ms preprocess, 6.7ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 7.2ms
# Speed: 0.8ms preprocess, 7.2ms inference, 0.8ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.0ms
# Speed: 0.6ms preprocess, 6.0ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.8ms
# Speed: 0.6ms preprocess, 5.8ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.8ms
# Speed: 0.6ms preprocess, 5.8ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.2ms
# Speed: 0.6ms preprocess, 6.2ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.7ms
# Speed: 0.6ms preprocess, 5.7ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.7ms
# Speed: 0.6ms preprocess, 5.7ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.7ms
# Speed: 0.6ms preprocess, 5.7ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.9ms
# Speed: 0.8ms preprocess, 6.9ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.1ms
# Speed: 0.7ms preprocess, 6.1ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.8ms
# Speed: 0.6ms preprocess, 6.8ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.8ms
# Speed: 0.7ms preprocess, 5.8ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 7.0ms
# Speed: 0.6ms preprocess, 7.0ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 9.7ms
# Speed: 0.7ms preprocess, 9.7ms inference, 1.1ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.6ms
# Speed: 0.9ms preprocess, 6.6ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.3ms
# Speed: 0.9ms preprocess, 6.3ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.3ms
# Speed: 0.8ms preprocess, 6.3ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.2ms
# Speed: 0.6ms preprocess, 5.2ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.5ms
# Speed: 0.6ms preprocess, 5.5ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.2ms
# Speed: 0.6ms preprocess, 6.2ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.8ms
# Speed: 0.7ms preprocess, 5.8ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 7.0ms
# Speed: 0.6ms preprocess, 7.0ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.3ms
# Speed: 0.6ms preprocess, 6.3ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.2ms
# Speed: 0.7ms preprocess, 5.2ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.7ms
# Speed: 0.7ms preprocess, 5.7ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.5ms
# Speed: 0.7ms preprocess, 5.5ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.6ms
# Speed: 0.6ms preprocess, 5.6ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.6ms
# Speed: 0.7ms preprocess, 6.6ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.1ms
# Speed: 0.6ms preprocess, 6.1ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 6 8s, 6.9ms
# Speed: 0.7ms preprocess, 6.9ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 6 8s, 6.3ms
# Speed: 0.6ms preprocess, 6.3ms inference, 1.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 6 8s, 5.8ms
# Speed: 1.0ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 1 0, 1 1, 1 4, 2 7s, 1 9, 6.6ms
# Speed: 0.6ms preprocess, 6.6ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 1 1, 1 4, 1 7, 5.9ms
# Speed: 0.8ms preprocess, 5.9ms inference, 1.1ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 1 1, 1 4, 1 7, 5.9ms
# Speed: 0.7ms preprocess, 5.9ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 6 .s, 6 0s, 6.1ms
# Speed: 0.6ms preprocess, 6.1ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 6 .s, 6 0s, 5.5ms
# Speed: 0.7ms preprocess, 5.5ms inference, 1.3ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 6 .s, 6 1s, 5.9ms
# Speed: 0.6ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 6 .s, 3 1s, 3 3s, 1 6, 5.4ms
# Speed: 0.6ms preprocess, 5.4ms inference, 1.1ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 6 .s, 6 2s, 5.7ms
# Speed: 0.6ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 6 .s, 3 2s, 1 3, 3 6s, 5.8ms
# Speed: 0.6ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 6 .s, 6 3s, 6.0ms
# Speed: 1.2ms preprocess, 6.0ms inference, 1.1ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 6 .s, 4 3s, 2 9s, 5.9ms
# Speed: 0.7ms preprocess, 5.9ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 6 .s, 6 4s, 5.9ms
# Speed: 0.7ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 6 .s, 6 4s, 5.7ms
# Speed: 0.6ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 6 .s, 6 5s, 5.8ms
# Speed: 0.7ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 6 .s, 6 5s, 6.1ms
# Speed: 0.6ms preprocess, 6.1ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 6 .s, 6 6s, 6.3ms
# Speed: 0.7ms preprocess, 6.3ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 6 .s, 6 6s, 6.2ms
# Speed: 0.6ms preprocess, 6.2ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 6 .s, 1 4, 5 7s, 1 9, 7.4ms
# Speed: 0.9ms preprocess, 7.4ms inference, 1.2ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 6 .s, 6 8s, 8.9ms
# Speed: 0.7ms preprocess, 8.9ms inference, 1.1ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 6 .s, 6 8s, 10.8ms
# Speed: 0.7ms preprocess, 10.8ms inference, 1.2ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 6 .s, 6 8s, 6.2ms
# Speed: 0.6ms preprocess, 6.2ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 6 .s, 2 8s, 4 9s, 5.4ms
# Speed: 0.6ms preprocess, 5.4ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 6.4ms
# Speed: 0.6ms preprocess, 6.4ms inference, 1.1ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.7ms
# Speed: 0.6ms preprocess, 5.7ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 5.8ms
# Speed: 0.6ms preprocess, 5.8ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 1 5, 3 8s, 5.3ms
# Speed: 0.7ms preprocess, 5.3ms inference, 1.6ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 1 0, 1 1, 1 2, 1 5, 7.3ms
# Speed: 0.6ms preprocess, 7.3ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 1 0, 1 5, 1 6, 1 9, 5.6ms
# Speed: 0.6ms preprocess, 5.6ms inference, 1.3ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 1 0, 1 1, 1 3, 1 5, 5.8ms
# Speed: 0.7ms preprocess, 5.8ms inference, 1.7ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 2 0s, 1 3, 1 5, 5.5ms
# Speed: 0.6ms preprocess, 5.5ms inference, 1.2ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 2 0s, 1 1, 1 4, 5.9ms
# Speed: 0.6ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 1 0, 1 2, 1 4, 1 9, 6.1ms
# Speed: 0.6ms preprocess, 6.1ms inference, 1.1ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 2 0s, 1 4, 1 7, 6.0ms
# Speed: 0.6ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 1 0, 1 4, 1 5, 1 8, 5.9ms
# Speed: 0.6ms preprocess, 5.9ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 2 0s, 1 2, 1 5, 5.7ms
# Speed: 0.6ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 1 0, 1 3, 2 5s, 5.7ms
# Speed: 0.6ms preprocess, 5.7ms inference, 1.5ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 1 0, 1 5, 2 8s, 5.9ms
# Speed: 0.7ms preprocess, 5.9ms inference, 1.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 1 0, 1 1, 1 5, 1 6, 1 9, 6.1ms
# Speed: 0.9ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 1 0, 1 3, 1 6, 1 8, 5.8ms
# Speed: 0.6ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 1 0, 1 4, 1 5, 1 6, 6.6ms
# Speed: 0.6ms preprocess, 6.6ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 2 0s, 1 1, 1 7, 5.5ms
# Speed: 0.6ms preprocess, 5.5ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 1 0, 1 2, 1 5, 1 7, 5.7ms
# Speed: 0.6ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 1 0, 1 7, 1 8, 1 9, 5.7ms
# Speed: 0.7ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 1 0, 1 5, 1 6, 1 7, 5.8ms
# Speed: 0.8ms preprocess, 5.8ms inference, 1.6ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 2 0s, 2 8s, 10.2ms
# Speed: 1.1ms preprocess, 10.2ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 1 0, 1 1, 1 5, 1 6, 1 8, 6.1ms
# Speed: 0.6ms preprocess, 6.1ms inference, 2.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 1 0, 3 8s, 6.0ms
# ...
# Speed: 1.1ms preprocess, 13.8ms inference, 2.2ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 2 0s, 1 3, 2 6s, 1 7, 12.4ms
# Speed: 1.3ms preprocess, 12.4ms inference, 1.1ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 2 0s, 1 4, 2 6s, 1 7, 10.7ms
# Speed: 1.5ms preprocess, 10.7ms inference, 2.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 2 0s, 1 5, 2 6s, 1 7, 11.9ms
# Speed: 1.1ms preprocess, 11.9ms inference, 1.2ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 2 0s, 2 6s, 2 7s, 10.3ms
# Speed: 0.9ms preprocess, 10.3ms inference, 1.7ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 2 0s, 2 6s, 2 8s, 9.2ms
# Speed: 1.2ms preprocess, 9.2ms inference, 2.9ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 2 0s, 1 1, 2 6s, 1 8, 15.0ms
# Speed: 0.9ms preprocess, 15.0ms inference, 2.1ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 2 0s, 1 3, 2 6s, 1 8, 14.9ms
# Speed: 0.9ms preprocess, 14.9ms inference, 1.8ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 2 0s, 2 6s, 1 8, 1 9, 11.9ms
# Speed: 0.9ms preprocess, 11.9ms inference, 1.2ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 1 0, 1 5, 2 6s, 1 7, 1 8, 14.3ms
# Speed: 1.0ms preprocess, 14.3ms inference, 1.5ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 1 0, 1 5, 2 6s, 2 8s, 12.0ms
# Speed: 0.9ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 1 0, 2 6s, 1 7, 2 8s, 13.0ms
# Speed: 1.3ms preprocess, 13.0ms inference, 2.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 2 0s, 1 3, 2 6s, 1 9, 14.0ms
# Speed: 1.6ms preprocess, 14.0ms inference, 1.1ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 1 0, 1 3, 1 5, 2 6s, 1 9, 12.1ms
# Speed: 1.1ms preprocess, 12.1ms inference, 1.2ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 1 0, 2 6s, 1 8, 2 9s, 12.5ms
# Speed: 1.4ms preprocess, 12.5ms inference, 2.1ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 1 0, 2 6s, 2 8s, 1 9, 11.0ms
# Speed: 0.9ms preprocess, 11.0ms inference, 1.3ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 3 0s, 1 5, 1 6, 1 7, 14.0ms
# Speed: 1.4ms preprocess, 14.0ms inference, 1.8ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 2 0s, 1 1, 1 5, 1 6, 1 7, 11.6ms
# Speed: 1.2ms preprocess, 11.6ms inference, 2.3ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 2 0s, 1 3, 1 5, 1 6, 1 7, 11.2ms
# Speed: 0.8ms preprocess, 11.2ms inference, 1.2ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 2 0s, 1 4, 1 5, 1 6, 1 7, 11.7ms
# Speed: 1.2ms preprocess, 11.7ms inference, 2.5ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 2 0s, 1 6, 1 7, 1 8, 1 9, 11.4ms
# Speed: 1.2ms preprocess, 11.4ms inference, 1.2ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 3 0s, 1 6, 1 7, 1 8, 11.5ms
# Speed: 1.1ms preprocess, 11.5ms inference, 4.6ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 2 0s, 1 5, 1 6, 1 7, 1 9, 12.0ms
# Speed: 1.1ms preprocess, 12.0ms inference, 1.7ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 2 0s, 1 1, 1 5, 1 6, 1 7, 12.2ms
# Speed: 1.3ms preprocess, 12.2ms inference, 1.5ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 1 0, 2 1s, 1 5, 1 6, 1 7, 10.8ms
# Speed: 3.2ms preprocess, 10.8ms inference, 1.3ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 1 0, 1 1, 2 5s, 1 6, 1 7, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 1.1ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 1 0, 1 1, 2 6s, 1 7, 1 8, 10.0ms
# Speed: 0.8ms preprocess, 10.0ms inference, 1.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 2 0s, 1 1, 1 6, 2 7s, 12.6ms
# Speed: 1.6ms preprocess, 12.6ms inference, 2.3ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 2 0s, 1 3, 2 6s, 1 7, 1 8, 12.1ms
# Speed: 1.0ms preprocess, 12.1ms inference, 1.7ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 2 0s, 1 1, 1 2, 1 6, 1 7, 13.9ms
# Speed: 1.6ms preprocess, 13.9ms inference, 1.7ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 2 0s, 1 2, 1 3, 1 6, 1 7, 11.2ms
# Speed: 1.1ms preprocess, 11.2ms inference, 2.6ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 2 0s, 1 2, 1 6, 1 7, 1 9, 13.0ms
# Speed: 1.3ms preprocess, 13.0ms inference, 1.5ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 2 0s, 1 2, 1 6, 2 7s, 13.7ms
# Speed: 1.0ms preprocess, 13.7ms inference, 1.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 2 0s, 1 2, 1 6, 1 7, 1 8, 13.9ms
# Speed: 3.8ms preprocess, 13.9ms inference, 1.3ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 1 0, 1 1, 1 3, 1 5, 1 6, 1 7, 10.8ms
# Speed: 1.5ms preprocess, 10.8ms inference, 2.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 1 0, 2 3s, 1 5, 1 6, 1 7, 10.9ms
# Speed: 1.4ms preprocess, 10.9ms inference, 2.8ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 1 0, 1 3, 1 5, 1 6, 1 7, 1 9, 12.5ms
# Speed: 1.1ms preprocess, 12.5ms inference, 2.3ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 1 0, 1 3, 1 6, 1 7, 1 8, 1 9, 14.2ms
# Speed: 1.2ms preprocess, 14.2ms inference, 1.8ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 2 0s, 1 3, 1 6, 2 7s, 11.4ms
# Speed: 1.5ms preprocess, 11.4ms inference, 1.7ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 2 0s, 1 4, 1 5, 1 6, 1 7, 12.3ms
# Speed: 1.9ms preprocess, 12.3ms inference, 1.1ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 2 0s, 1 4, 1 6, 1 7, 1 8, 10.0ms
# Speed: 0.9ms preprocess, 10.0ms inference, 2.1ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 2 0s, 1 3, 1 4, 1 6, 1 7, 14.1ms
# Speed: 1.4ms preprocess, 14.1ms inference, 1.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 2 0s, 2 4s, 1 6, 1 7, 15.1ms
# Speed: 1.4ms preprocess, 15.1ms inference, 1.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 1 0, 1 4, 2 5s, 1 6, 1 7, 11.7ms
# Speed: 3.9ms preprocess, 11.7ms inference, 1.5ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 1 0, 1 4, 1 5, 1 6, 2 7s, 11.4ms
# Speed: 1.2ms preprocess, 11.4ms inference, 1.9ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 1 0, 1 5, 1 6, 1 7, 1 8, 1 9, 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 1.3ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 1 0, 1 1, 2 5s, 1 6, 1 7, 14.4ms
# Speed: 1.1ms preprocess, 14.4ms inference, 1.7ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 1 0, 1 3, 2 5s, 1 6, 1 7, 11.3ms
# Speed: 1.4ms preprocess, 11.3ms inference, 1.8ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 2 0s, 1 4, 1 5, 1 6, 1 7, 12.5ms
# Speed: 1.4ms preprocess, 12.5ms inference, 1.9ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 2 0s, 1 5, 1 6, 2 7s, 12.4ms
# Speed: 1.1ms preprocess, 12.4ms inference, 1.2ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 1 0, 2 5s, 1 6, 2 7s, 10.9ms
# Speed: 0.8ms preprocess, 10.9ms inference, 1.5ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 1 0, 1 5, 2 6s, 1 7, 1 8, 14.6ms
# Speed: 1.5ms preprocess, 14.6ms inference, 3.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 1 0, 1 1, 1 5, 2 6s, 1 7, 11.9ms
# Speed: 1.0ms preprocess, 11.9ms inference, 1.8ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 1 0, 1 2, 1 5, 2 6s, 1 7, 11.2ms
# Speed: 1.1ms preprocess, 11.2ms inference, 1.5ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 2 0s, 1 4, 2 6s, 1 7, 13.0ms
# Speed: 1.1ms preprocess, 13.0ms inference, 1.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 2 0s, 2 6s, 2 7s, 10.5ms
# Speed: 1.4ms preprocess, 10.5ms inference, 1.5ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 1 0, 1 5, 2 6s, 2 7s, 10.7ms
# Speed: 1.3ms preprocess, 10.7ms inference, 2.1ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 1 0, 1 5, 1 6, 1 7, 2 8s, 14.0ms
# Speed: 1.1ms preprocess, 14.0ms inference, 2.3ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 2 0s, 1 1, 1 6, 2 7s, 11.3ms
# Speed: 1.0ms preprocess, 11.3ms inference, 1.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 2 0s, 1 2, 1 6, 2 7s, 12.6ms
# Speed: 1.4ms preprocess, 12.6ms inference, 3.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 2 0s, 1 6, 2 7s, 1 9, 14.4ms
# Speed: 1.0ms preprocess, 14.4ms inference, 1.8ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 1 0, 2 5s, 1 6, 2 7s, 16.9ms
# Speed: 1.0ms preprocess, 16.9ms inference, 2.8ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 1 0, 1 6, 2 7s, 2 8s, 13.5ms
# Speed: 1.2ms preprocess, 13.5ms inference, 1.7ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 1 0, 1 6, 2 7s, 1 8, 1 9, 13.4ms
# Speed: 1.4ms preprocess, 13.4ms inference, 2.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 1 0, 1 6, 1 7, 3 8s, 18.1ms
# Speed: 1.6ms preprocess, 18.1ms inference, 3.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 2 0s, 1 1, 1 6, 1 7, 1 8, 16.9ms
# Speed: 1.4ms preprocess, 16.9ms inference, 1.8ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 2 0s, 1 4, 1 6, 1 7, 1 8, 10.4ms
# Speed: 1.1ms preprocess, 10.4ms inference, 1.2ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 1 0, 1 5, 2 6s, 1 7, 1 8, 13.2ms
# Speed: 1.2ms preprocess, 13.2ms inference, 1.7ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 1 0, 1 5, 1 6, 1 7, 2 8s, 12.1ms
# Speed: 2.7ms preprocess, 12.1ms inference, 1.1ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 2 0s, 1 1, 1 6, 1 7, 1 9, 10.9ms
# Speed: 3.3ms preprocess, 10.9ms inference, 2.8ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 2 0s, 1 3, 1 6, 1 7, 1 9, 14.7ms
# Speed: 1.1ms preprocess, 14.7ms inference, 1.7ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 2 0s, 1 4, 1 6, 1 7, 1 9, 11.5ms
# Speed: 1.4ms preprocess, 11.5ms inference, 1.2ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 1 0, 1 5, 1 6, 1 7, 2 9s, 13.4ms
# Speed: 0.8ms preprocess, 13.4ms inference, 2.8ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 1 0, 1 5, 1 6, 2 7s, 1 9, 11.5ms
# Speed: 1.1ms preprocess, 11.5ms inference, 1.5ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 1 0, 1 5, 1 6, 1 7, 1 8, 1 9, 18.2ms
# Speed: 1.2ms preprocess, 18.2ms inference, 2.5ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 3 0s, 1 1, 1 6, 1 8, 14.2ms
# Speed: 0.8ms preprocess, 14.2ms inference, 2.1ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 3 0s, 1 3, 1 6, 1 8, 9.9ms
# Speed: 1.0ms preprocess, 9.9ms inference, 2.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 3 0s, 1 4, 1 6, 1 8, 11.5ms
# Speed: 1.0ms preprocess, 11.5ms inference, 3.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 2 0s, 1 4, 1 5, 1 6, 1 8, 13.4ms
# Speed: 1.3ms preprocess, 13.4ms inference, 1.3ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 3 0s, 1 6, 1 7, 1 8, 9.8ms
# Speed: 0.8ms preprocess, 9.8ms inference, 1.3ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 3 0s, 1 6, 2 8s, 14.4ms
# Speed: 1.0ms preprocess, 14.4ms inference, 1.1ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 2 0s, 1 1, 1 5, 1 6, 1 8, 12.1ms
# Speed: 1.0ms preprocess, 12.1ms inference, 3.2ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 1 0, 1 1, 1 3, 1 5, 1 6, 1 8, 12.0ms
# Speed: 0.9ms preprocess, 12.0ms inference, 1.8ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 1 0, 1 1, 1 4, 1 5, 1 6, 1 8, 13.4ms
# Speed: 3.7ms preprocess, 13.4ms inference, 1.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 1 0, 1 1, 1 5, 1 6, 2 8s, 10.9ms
# Speed: 0.8ms preprocess, 10.9ms inference, 1.5ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 1 0, 1 1, 1 5, 1 6, 1 7, 1 8, 9.7ms
# Speed: 1.3ms preprocess, 9.7ms inference, 2.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 1 0, 1 1, 1 5, 1 6, 2 8s, 10.9ms
# Speed: 1.3ms preprocess, 10.9ms inference, 2.3ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 1 0, 1 5, 2 6s, 2 8s, 12.9ms
# Speed: 1.1ms preprocess, 12.9ms inference, 2.6ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 2 0s, 2 2s, 1 6, 1 8, 13.5ms
# Speed: 1.1ms preprocess, 13.5ms inference, 3.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 1 0, 1 2, 1 4, 1 5, 1 6, 1 8, 10.6ms
# Speed: 1.3ms preprocess, 10.6ms inference, 2.8ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 1 0, 1 2, 2 5s, 1 6, 1 8, 9.6ms
# Speed: 1.1ms preprocess, 9.6ms inference, 1.5ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 2 0s, 1 2, 1 6, 1 7, 1 8, 12.5ms
# Speed: 1.1ms preprocess, 12.5ms inference, 4.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 1 0, 1 2, 1 5, 1 6, 2 8s, 10.5ms
# Speed: 1.0ms preprocess, 10.5ms inference, 2.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 1 0, 1 3, 1 6, 3 8s, 13.8ms
# Speed: 1.5ms preprocess, 13.8ms inference, 2.2ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 2 0s, 1 2, 1 3, 1 6, 1 8, 13.3ms
# Speed: 0.9ms preprocess, 13.3ms inference, 1.7ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 2 0s, 1 3, 1 6, 1 8, 1 9, 10.8ms
# Speed: 1.3ms preprocess, 10.8ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 1 0, 1 3, 1 5, 1 6, 1 8, 1 9, 14.8ms
# Speed: 1.1ms preprocess, 14.8ms inference, 2.3ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 1 0, 1 3, 1 6, 3 8s, 13.2ms
# Speed: 1.2ms preprocess, 13.2ms inference, 3.3ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 1 0, 1 3, 1 5, 1 6, 1 8, 1 9, 11.5ms
# Speed: 1.1ms preprocess, 11.5ms inference, 3.1ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 2 0s, 1 1, 1 4, 1 6, 1 8, 13.1ms
# Speed: 2.6ms preprocess, 13.1ms inference, 1.7ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 2 0s, 1 3, 1 4, 1 6, 1 8, 16.5ms
# Speed: 1.1ms preprocess, 16.5ms inference, 1.3ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 1 0, 1 2, 1 4, 1 5, 1 6, 1 8, 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 3.3ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 1 0, 2 4s, 1 5, 1 6, 1 8, 10.8ms
# Speed: 1.2ms preprocess, 10.8ms inference, 2.2ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 1 0, 1 4, 1 5, 1 6, 1 7, 1 8, 13.2ms
# Speed: 1.9ms preprocess, 13.2ms inference, 2.1ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 1 0, 1 4, 1 6, 3 8s, 12.4ms
# Speed: 1.2ms preprocess, 12.4ms inference, 1.9ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 1 0, 1 5, 1 6, 2 8s, 1 9, 12.0ms
# Speed: 1.5ms preprocess, 12.0ms inference, 1.6ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 1 0, 1 1, 2 5s, 1 6, 1 8, 11.9ms
# Speed: 1.4ms preprocess, 11.9ms inference, 3.5ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 1 0, 1 3, 2 5s, 1 6, 1 8, 13.1ms
# Speed: 2.8ms preprocess, 13.1ms inference, 1.2ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 1 0, 2 5s, 1 6, 1 8, 1 9, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 1.7ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 ., 2 0s, 1 5, 1 6, 1 7, 1 8, 12.7ms
# Speed: 1.5ms preprocess, 12.7ms inference, 1.8ms postprocess per image at shape (1, 3, 544, 640)

# %% [markdown]
# # 2. Perdict image

# %%
from ultralytics import YOLO
import cv2
import torch

# Load the YOLO model
model = YOLO("Model/yolo11s_30k_images_64_epochs_grayscale_only.pt")
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')  # Use GPU if available
model = model.to(device)

# Image path
image_path = "Data/test/test_image1.png"  # Replace with your image path

# Read the image
img = cv2.imread(image_path)

# Check if image opened successfully
if img is None:
    print("Error opening image file")
    exit()

# Perform inference on the image
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY) #convert to gray
results = model(img_gray, ch=1) #run the model with one channel

# Annotate the frame with bounding boxes and labels
annotated_frame = results[0].plot(img=img)  # Plot a single result on the frame

for i, result in enumerate(results):
    boxes = result.boxes
    sorted_boxes = sorted(
        boxes,
        key=lambda b: b.xyxy[0][0].item()
    )

    digits_in_frame = []
    for box in sorted_boxes:
        class_idx = int(box.cls[0].item())
        class_name = result.names[class_idx]
        digits_in_frame.append(class_name)

    text_result = ''.join(digits_in_frame)

position = (10, 100)
font = cv2.FONT_HERSHEY_DUPLEX
font_scale = 3
thickness = 3

annotated_frame = cv2.putText(annotated_frame, text_result, position, font, font_scale, (0, 255, 0), thickness)

# Display the annotated frame
#cv2.imshow('YOLO Image', annotated_frame)
#cv2.waitKey(0)  # Wait for a key press to close the window
#cv2.destroyAllWindows()


# Save the annotated image
output_path = "result_image_1.jpg"  # Replace with your desired output path
cv2.imwrite(output_path, annotated_frame)
# Out:
# 0: 640x640 1 ., 1 0, 1 1, 1 2, 1 3, 1 8, 1 9, 5.0ms
# Speed: 2.6ms preprocess, 5.0ms inference, 271.1ms postprocess per image at shape (1, 3, 640, 640)
# True

# %% [markdown]
# # 3. Live camera using opencv / raspberry pi

# %%
from ultralytics import YOLO
import cv2
import torch

# Load the YOLO model
model = YOLO("Model/yolo11s_30k_images_64_epochs_grayscale_only.pt")
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')  # Use GPU if available
model = model.to(device)

# Open the default camera (usually index 0).  Change if needed.
cap = cv2.VideoCapture(0)  # Use 0 for default camera, 1 for external, etc.

# Check if camera opened successfully
if not cap.isOpened():
    print("Error opening camera")
    exit()

while(cap.isOpened()):
    ret, frame = cap.read()
    if ret:
        # Perform inference on the frame
        frame_gray = cv2.cvtColor(frame, cv2.COLOR_RGB2GRAY) # Convert to grayscale
        results = model(frame_gray, ch=1) # Run inference

        # Annotate the frame with bounding boxes and labels
        annotated_frame = results[0].plot(img=frame) #Plot a single result on the frame

        for i, result in enumerate(results):
            boxes = result.boxes
            sorted_boxes = sorted(
                boxes,
                key=lambda b: b.xyxy[0][0].item()
            )
            
            digits_in_frame = []
            for box in sorted_boxes:
                class_idx = int(box.cls[0].item())
                class_name = result.names[class_idx]
                digits_in_frame.append(class_name)

            text_result = ''.join(digits_in_frame)

        position = (10, 100) 
        font = cv2.FONT_HERSHEY_DUPLEX
        font_scale = 3
        thickness = 3

        annotated_frame = cv2.putText(annotated_frame, text_result, position, font, font_scale, (0, 255, 0), thickness)

        # Display the annotated frame
        cv2.imshow('YOLO Live', annotated_frame) # Show the live feed


        # Press 'q' to exit
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    else:
        break

# Release the capture object
cap.release()
cv2.destroyAllWindows()
