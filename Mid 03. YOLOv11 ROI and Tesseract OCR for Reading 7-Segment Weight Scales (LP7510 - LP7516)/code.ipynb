# %% [markdown]
# # Please use one of the following methods for inference with the model.
#
# #### 1. Predict video
# #### 2. Predict image
# #### 3. Live camera

# %% [markdown]
# # Before starting, modify your Ultralytics library to handle grayscale images (see the README.md file).

# %% [markdown]
# # 1. Predict video

# %%
from ultralytics import YOLO
import cv2
import torch
import pytesseract

# Load the YOLO model
model_path = '/home/font/LearnDL/Z-Yolo11 LP7510 only/runs/detect/train11/weights/yolov11n gray scale roi.pt'
model = YOLO(model_path)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')  # Use GPU if available
model = model.to(device)

# Video path
video_path = "Data/test/test5fps.mp4"  # Replace with your video path

# Open the video file
cap = cv2.VideoCapture(video_path)

# Check if video opened successfully
if not cap.isOpened():
    print("Error opening video file")
    exit()

# Get video properties (optional)
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = cap.get(cv2.CAP_PROP_FPS)
fourcc = cv2.VideoWriter_fourcc(*'mp4v') # Codec for output video
out = cv2.VideoWriter('result_video_1.mp4', fourcc, fps, (width, height)) # Output video writer

while(cap.isOpened()):
    ret, frame = cap.read()
    if ret:
        # Perform inference on the frame
        frame_gray = cv2.cvtColor(frame, cv2.COLOR_RGB2GRAY)
        results = model(frame_gray, ch=1)
        frame_result = results[0].plot(img=frame)
        try:
            first_box = results[0].boxes[0]
            x1, y1, x2, y2 = first_box.xyxy[0]
            x1, y1, x2, y2 = map(int, [x1, y1, x2, y2])
            cropped_image = frame_gray[y1:y2, x1:x2]

        except Exception:
            cropped_image = frame_gray
        
        text4 = pytesseract.pytesseract.image_to_string(cropped_image, lang='7seg', config='--psm 6 --oem 3 -c tessedit_char_whitelist=.0123456789 -c tessedit_char_blacklist=abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ:')

        position = (10, 100)  # Bottom-left corner of the text
        font = cv2.FONT_HERSHEY_DUPLEX
        font_scale = 3
        thickness = 3

        # Annotate the frame with bounding boxes and labels
        annotated_frame = cv2.putText(frame_result, text4[:-1], position, font, font_scale, (0, 255, 0), thickness)

        # Display the annotated frame
        #cv2.imshow('YOLO Video', annotated_frame)
        out.write(annotated_frame)

        # Press 'q' to exit
        #if cv2.waitKey(1) & 0xFF == ord('q'):
           # break
    else:
        break

# Release the video capture and writer objects
cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# 0: 544x640 1 Display, 50.7ms
# Speed: 79.0ms preprocess, 50.7ms inference, 1212.3ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 18.9ms
# Speed: 1.0ms preprocess, 18.9ms inference, 1.5ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 43.1ms
# Speed: 1.5ms preprocess, 43.1ms inference, 4.3ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 35.0ms
# Speed: 1.4ms preprocess, 35.0ms inference, 5.8ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 29.9ms
# Speed: 1.3ms preprocess, 29.9ms inference, 3.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 28.8ms
# Speed: 1.4ms preprocess, 28.8ms inference, 1.6ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 25.9ms
# Speed: 1.2ms preprocess, 25.9ms inference, 1.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 24.2ms
# Speed: 1.4ms preprocess, 24.2ms inference, 2.1ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 24.3ms
# Speed: 1.4ms preprocess, 24.3ms inference, 2.9ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 27.7ms
# Speed: 1.3ms preprocess, 27.7ms inference, 4.1ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 26.5ms
# Speed: 1.2ms preprocess, 26.5ms inference, 2.9ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 34.4ms
# Speed: 1.3ms preprocess, 34.4ms inference, 1.7ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 27.5ms
# Speed: 1.5ms preprocess, 27.5ms inference, 1.3ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 25.5ms
# Speed: 1.1ms preprocess, 25.5ms inference, 4.5ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 28.6ms
# Speed: 1.8ms preprocess, 28.6ms inference, 3.6ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 23.2ms
# Speed: 1.6ms preprocess, 23.2ms inference, 3.5ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 29.4ms
# Speed: 1.3ms preprocess, 29.4ms inference, 1.8ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 35.2ms
# Speed: 1.2ms preprocess, 35.2ms inference, 3.7ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 31.1ms
# Speed: 1.4ms preprocess, 31.1ms inference, 2.8ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 25.3ms
# Speed: 3.7ms preprocess, 25.3ms inference, 3.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 25
3ms inference, 1.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 15.4ms
# Speed: 1.4ms preprocess, 15.4ms inference, 3.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 27.2ms
# Speed: 1.9ms preprocess, 27.2ms inference, 1.8ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 31.0ms
# Speed: 1.8ms preprocess, 31.0ms inference, 1.8ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 18.2ms
# Speed: 3.8ms preprocess, 18.2ms inference, 1.5ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 14.5ms
# Speed: 1.1ms preprocess, 14.5ms inference, 2.6ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 17.9ms
# Speed: 1.7ms preprocess, 17.9ms inference, 1.6ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 15.0ms
# Speed: 1.1ms preprocess, 15.0ms inference, 1.5ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 18.5ms
# Speed: 3.1ms preprocess, 18.5ms inference, 3.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 23.9ms
# Speed: 1.1ms preprocess, 23.9ms inference, 1.7ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 19.5ms
# Speed: 1.4ms preprocess, 19.5ms inference, 2.5ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 17.8ms
# Speed: 1.3ms preprocess, 17.8ms inference, 4.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 16.6ms
# Speed: 1.2ms preprocess, 16.6ms inference, 4.5ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 15.1ms
# Speed: 1.6ms preprocess, 15.1ms inference, 5.1ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 15.8ms
# Speed: 1.4ms preprocess, 15.8ms inference, 2.1ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 20.0ms
# Speed: 3.7ms preprocess, 20.0ms inference, 1.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 19.3ms
# Speed: 1.2ms preprocess, 19.3ms inference, 1.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 20.2ms
# Speed: 1.4ms preprocess, 20.2ms inference, 1.5ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 26.6ms
# Speed: 1.1ms preprocess, 26.6ms inference, 2.2ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 26.4ms
# Speed: 1.1ms preprocess, 26.4ms inference, 1.8ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 19.8ms
# Speed: 1.2ms preprocess, 19.8ms inference, 1.9ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 21.0ms
# Speed: 1.2ms preprocess, 21.0ms inference, 1.9ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 21.1ms
# Speed: 1.5ms preprocess, 21.1ms inference, 2.2ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 19.5ms
# Speed: 1.5ms preprocess, 19.5ms inference, 1.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 14.8ms
# Speed: 2.0ms preprocess, 14.8ms inference, 1.3ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 19.8ms
# Speed: 1.1ms preprocess, 19.8ms inference, 2.8ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 27.7ms
# Speed: 1.6ms preprocess, 27.7ms inference, 1.9ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 33.2ms
# Speed: 2.6ms preprocess, 33.2ms inference, 2.3ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 21.7ms
# Speed: 1.1ms preprocess, 21.7ms inference, 1.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 15.0ms
# Speed: 2.6ms preprocess, 15.0ms inference, 1.8ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 17.4ms
# Speed: 1.2ms preprocess, 17.4ms inference, 1.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 24.1ms
# Speed: 1.2ms preprocess, 24.1ms inference, 2.8ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 17.2ms
# Speed: 1.7ms preprocess, 17.2ms inference, 3.1ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 17.7ms
# Speed: 1.4ms preprocess, 17.7ms inference, 1.5ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 19.9ms
# Speed: 1.4ms preprocess, 19.9ms inference, 1.6ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 22.2ms
# Speed: 1.2ms preprocess, 22.2ms inference, 2.7ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 16.9ms
# Speed: 1.4ms preprocess, 16.9ms inference, 1.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 18.9ms
# Speed: 2.3ms preprocess, 18.9ms inference, 4.8ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 17.6ms
# Speed: 1.2ms preprocess, 17.6ms inference, 1.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 17.8ms
# Speed: 1.5ms preprocess, 17.8ms inference, 3.2ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 17.6ms
# Speed: 1.2ms preprocess, 17.6ms inference, 2.5ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 21.8ms
# Speed: 1.6ms preprocess, 21.8ms inference, 2.3ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 21.7ms
# Speed: 1.4ms preprocess, 21.7ms inference, 1.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 20.3ms
# Speed: 1.1ms preprocess, 20.3ms inference, 3.9ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 17.8ms
# Speed: 1.3ms preprocess, 17.8ms inference, 2.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 23.0ms
# Speed: 2.3ms preprocess, 23.0ms inference, 1.6ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 17.1ms
# Speed: 1.4ms preprocess, 17.1ms inference, 1.8ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 22.2ms
# Speed: 1.2ms preprocess, 22.2ms inference, 1.6ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 15.3ms
# Speed: 1.4ms preprocess, 15.3ms inference, 2.1ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 20.3ms
# Speed: 1.7ms preprocess, 20.3ms inference, 2.6ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 18.3ms
# Speed: 1.1ms preprocess, 18.3ms inference, 1.9ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 17.6ms
# Speed: 1.0ms preprocess, 17.6ms inference, 1.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 17.5ms
# Speed: 1.6ms preprocess, 17.5ms inference, 1.7ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 27.0ms
# Speed: 3.3ms preprocess, 27.0ms inference, 2.1ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 17.7ms
# Speed: 1.5ms preprocess, 17.7ms inference, 1.5ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 19.1ms
# Speed: 1.1ms preprocess, 19.1ms inference, 2.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 17.6ms
# Speed: 1.8ms preprocess, 17.6ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 24.6ms
# Speed: 1.2ms preprocess, 24.6ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 19.0ms
# Speed: 1.3ms preprocess, 19.0ms inference, 0.8ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 20.2ms
# Speed: 1.9ms preprocess, 20.2ms inference, 1.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 24.1ms
# Speed: 1.2ms preprocess, 24.1ms inference, 1.3ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 15.1ms
# Speed: 1.1ms preprocess, 15.1ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 22.0ms
# Speed: 1.1ms preprocess, 22.0ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections), 29.4ms
# Speed: 3.4ms preprocess, 29.4ms inference, 2.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 (no detections),
0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 19.2ms
# Speed: 1.2ms preprocess, 19.2ms inference, 3.1ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 22.2ms
# Speed: 1.7ms preprocess, 22.2ms inference, 5.5ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 24.2ms
# Speed: 1.8ms preprocess, 24.2ms inference, 2.5ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 31.8ms
# Speed: 1.6ms preprocess, 31.8ms inference, 2.7ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 32.7ms
# Speed: 1.1ms preprocess, 32.7ms inference, 1.3ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 28.1ms
# Speed: 1.3ms preprocess, 28.1ms inference, 1.3ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 22.9ms
# Speed: 3.3ms preprocess, 22.9ms inference, 2.5ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 17.9ms
# Speed: 1.2ms preprocess, 17.9ms inference, 6.3ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 18.4ms
# Speed: 1.2ms preprocess, 18.4ms inference, 1.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 31.3ms
# Speed: 1.4ms preprocess, 31.3ms inference, 3.2ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 26.6ms
# Speed: 1.4ms preprocess, 26.6ms inference, 3.7ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 20.2ms
# Speed: 1.2ms preprocess, 20.2ms inference, 6.8ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 17.7ms
# Speed: 2.5ms preprocess, 17.7ms inference, 3.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 20.0ms
# Speed: 1.3ms preprocess, 20.0ms inference, 1.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 21.5ms
# Speed: 1.0ms preprocess, 21.5ms inference, 4.1ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 21.4ms
# Speed: 1.2ms preprocess, 21.4ms inference, 1.7ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 25.1ms
# Speed: 1.5ms preprocess, 25.1ms inference, 5.7ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 18.7ms
# Speed: 1.1ms preprocess, 18.7ms inference, 1.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 19.3ms
# Speed: 3.0ms preprocess, 19.3ms inference, 2.5ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 20.6ms
# Speed: 1.4ms preprocess, 20.6ms inference, 2.2ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 28.8ms
# Speed: 1.5ms preprocess, 28.8ms inference, 2.9ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 20.6ms
# Speed: 1.0ms preprocess, 20.6ms inference, 1.5ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 27.0ms
# Speed: 2.0ms preprocess, 27.0ms inference, 1.7ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 22.7ms
# Speed: 1.2ms preprocess, 22.7ms inference, 2.2ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 18.1ms
# Speed: 1.5ms preprocess, 18.1ms inference, 1.7ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 22.2ms
# Speed: 1.3ms preprocess, 22.2ms inference, 3.1ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 24.5ms
# Speed: 4.0ms preprocess, 24.5ms inference, 4.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 15.0ms
# Speed: 1.5ms preprocess, 15.0ms inference, 2.1ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 27.9ms
# Speed: 1.9ms preprocess, 27.9ms inference, 3.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 22.3ms
# Speed: 1.1ms preprocess, 22.3ms inference, 5.5ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 32.3ms
# Speed: 1.3ms preprocess, 32.3ms inference, 1.7ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 25.3ms
# Speed: 2.0ms preprocess, 25.3ms inference, 2.9ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 16.8ms
# Speed: 1.6ms preprocess, 16.8ms inference, 2.5ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 20.8ms
# Speed: 2.1ms preprocess, 20.8ms inference, 3.8ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 23.5ms
# Speed: 1.1ms preprocess, 23.5ms inference, 1.5ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 28.6ms
# Speed: 3.0ms preprocess, 28.6ms inference, 1.8ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 19.8ms
# Speed: 1.7ms preprocess, 19.8ms inference, 6.7ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 22.0ms
# Speed: 1.3ms preprocess, 22.0ms inference, 4.3ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 17.5ms
# Speed: 1.5ms preprocess, 17.5ms inference, 1.9ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 27.9ms
# Speed: 1.3ms preprocess, 27.9ms inference, 3.1ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 22.5ms
# Speed: 1.4ms preprocess, 22.5ms inference, 1.3ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 21.5ms
# Speed: 1.1ms preprocess, 21.5ms inference, 4.3ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 21.5ms
# Speed: 1.7ms preprocess, 21.5ms inference, 1.8ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 28.2ms
# Speed: 1.2ms preprocess, 28.2ms inference, 2.9ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 18.7ms
# Speed: 1.2ms preprocess, 18.7ms inference, 6.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 18.1ms
# Speed: 1.3ms preprocess, 18.1ms inference, 8.3ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 26.8ms
# Speed: 2.2ms preprocess, 26.8ms inference, 3.3ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 20.8ms
# Speed: 1.3ms preprocess, 20.8ms inference, 1.3ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 28.4ms
# Speed: 1.4ms preprocess, 28.4ms inference, 4.1ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 22.6ms
# Speed: 1.1ms preprocess, 22.6ms inference, 1.8ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 18.5ms
# Speed: 1.2ms preprocess, 18.5ms inference, 5.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 17.7ms
# Speed: 1.3ms preprocess, 17.7ms inference, 3.1ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 19.0ms
# Speed: 1.0ms preprocess, 19.0ms inference, 1.2ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 18.2ms
# Speed: 1.6ms preprocess, 18.2ms inference, 3.3ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 20.3ms
# Speed: 1.2ms preprocess, 20.3ms inference, 4.3ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 39.0ms
# Speed: 1.2ms preprocess, 39.0ms inference, 4.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 22.2ms
# Speed: 1.3ms preprocess, 22.2ms inference, 3.8ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 18.6ms
# Speed: 1.9ms preprocess, 18.6ms inference, 5.7ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 20.6ms
# Speed: 1.1ms preprocess, 20.6ms inference, 1.8ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 30.1ms
# Speed: 1.5ms preprocess, 30.1ms inference, 2.2ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 18.1ms
# Speed: 1.2ms preprocess, 18.1ms inference, 1.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 18.5ms
# Speed: 1.1ms preprocess, 18.5ms inference, 4.2ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 26.4ms
# Speed: 1.2ms preprocess, 26.4ms inference, 2.6ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 18.0ms
# Speed: 1.2ms preprocess, 18.0ms inference, 1.8ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 22.0ms
# Speed: 1.4ms preprocess, 22.0ms inference, 3.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 28.5ms
# Speed: 1.2ms preprocess, 28.5ms inference, 4.7ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 19.6ms
# Speed: 1.3ms preprocess, 19.6ms inference, 3.5ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 18.1ms
# Speed: 1.2ms preprocess, 18.1ms inference, 1.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 22.7ms
# Speed: 1.5ms preprocess, 22.7ms inference, 1.7ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 18.6ms
# Speed: 1.6ms preprocess, 18.6ms inference, 2.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 14.6ms
# Speed: 1.3ms preprocess, 14.6ms inference, 3.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 28.5ms
# Speed: 1.9ms preprocess, 28.5ms inference, 1.9ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 31.6ms
# Speed: 1.4ms preprocess, 31.6ms inference, 1.5ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 24.1ms
# Speed: 1.3ms preprocess, 24.1ms inference, 3.6ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 23.8ms
# Speed: 1.0ms preprocess, 23.8ms inference, 5.5ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 34.6ms
# Speed: 1.3ms preprocess, 34.6ms inference, 1.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 26.9ms
# Speed: 1.5ms preprocess, 26.9ms inference, 1.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 20.3ms
# Speed: 1.1ms preprocess, 20.3ms inference, 6.9ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 19.3ms
# Speed: 1.1ms preprocess, 19.3ms inference, 1.3ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 19.8ms
# Speed: 1.8ms preprocess, 19.8ms inference, 4.2ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 22.0ms
# Speed: 1.2ms preprocess, 22.0ms inference, 4.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 15.1ms
# Speed: 1.5ms preprocess, 15.1ms inference, 1.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 25.7ms
# Speed: 1.6ms preprocess, 25.7ms inference, 4.5ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 28.2ms
# Speed: 1.5ms preprocess, 28.2ms inference, 3.2ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 18.7ms
# Speed: 1.3ms preprocess, 18.7ms inference, 1.7ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 17.4ms
# Speed: 1.7ms preprocess, 17.4ms inference, 2.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 21.5ms
# Speed: 1.3ms preprocess, 21.5ms inference, 4.5ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 18.5ms
# Speed: 2.2ms preprocess, 18.5ms inference, 6.1ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 16.6ms
# Speed: 1.2ms preprocess, 16.6ms inference, 3.9ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 27.9ms
# Speed: 5.8ms preprocess, 27.9ms inference, 1.3ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 26.0ms
# Speed: 1.3ms preprocess, 26.0ms inference, 5.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 27.8ms
# Speed: 1.8ms preprocess, 27.8ms inference, 1.9ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 19.3ms
# Speed: 1.1ms preprocess, 19.3ms inference, 4.3ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 21.4ms
# Speed: 1.6ms preprocess, 21.4ms inference, 3.6ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 20.6ms
# Speed: 1.2ms preprocess, 20.6ms inference, 3.8ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 22.5ms
# Speed: 1.0ms preprocess, 22.5ms inference, 3.3ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 25.6ms
# Speed: 2.8ms preprocess, 25.6ms inference, 1.3ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 20.2ms
# Speed: 1.2ms preprocess, 20.2ms inference, 3.5ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 17.9ms
# Speed: 1.5ms preprocess, 17.9ms inference, 1.2ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 21.3ms
# Speed: 1.6ms preprocess, 21.3ms inference, 4.2ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 38.5ms
# Speed: 1.2ms preprocess, 38.5ms inference, 4.3ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 Display, 19.2ms
# Speed: 1.5ms preprocess, 19.2ms inference, 8.3ms postprocess per image at shape (1, 3, 544, 640)

# %% [markdown]
# # 2. Perdict image

# %%
from ultralytics import YOLO
import cv2
import torch
import pytesseract

# Load the YOLO model
model_path = '/home/font/LearnDL/Z-Yolo11 LP7510 only/runs/detect/train11/weights/yolov11n gray scale roi.pt'
model = YOLO(model_path)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')  # Use GPU if available
model = model.to(device)

# Image path
image_path = "Data/test/test_image1.png"  # Replace with your image path

frame = cv2.imread(image_path)

if frame is None:
    print("Error opening image file")
    exit()

# Perform inference on the frame
frame_gray = cv2.cvtColor(frame, cv2.COLOR_RGB2GRAY)
results = model(frame_gray, ch=1)
frame_result = results[0].plot(img=frame)
try:
    first_box = results[0].boxes[0]
    x1, y1, x2, y2 = first_box.xyxy[0]
    x1, y1, x2, y2 = map(int, [x1, y1, x2, y2])
    cropped_image = frame_gray[y1:y2, x1:x2]

except Exception:
    cropped_image = frame_gray

text4 = pytesseract.pytesseract.image_to_string(cropped_image, lang='7seg', config='--psm 6 --oem 3 -c tessedit_char_whitelist=.0123456789 -c tessedit_char_blacklist=abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ:')

position = (10, 100)  # Bottom-left corner of the text
font = cv2.FONT_HERSHEY_DUPLEX
font_scale = 3
thickness = 3

# Annotate the frame with bounding boxes and labels
annotated_frame = cv2.putText(frame_result, text4[:-1], position, font, font_scale, (0, 255, 0), thickness)

# Display the annotated frame
#cv2.imshow('YOLO Image', annotated_frame)
#cv2.waitKey(0)
#cv2.destroyAllWindows()

# Save the annotated image
output_path = "result_image_1.jpg"  # Replace with your desired output path
cv2.imwrite(output_path, annotated_frame)
# Out:
# 0: 640x640 1 Display, 45.3ms
# Speed: 1.3ms preprocess, 45.3ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 640)
# True

# %% [markdown]
# # 3. Live camera using opencv / raspberry pi

# %%
from ultralytics import YOLO
import cv2
import torch
import pytesseract

# Load the YOLO model
model_path = '/home/font/LearnDL/Z-Yolo11 LP7510 only/runs/detect/train11/weights/yolov11n gray scale roi.pt'
model = YOLO(model_path)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')  # Use GPU if available
model = model.to(device)

# Open the default camera (usually index 0).  Change if needed.
cap = cv2.VideoCapture(0)

# Check if camera opened successfully
if not cap.isOpened():
    print("Error opening camera")
    exit()


while(cap.isOpened()):
    ret, frame = cap.read()
    if ret:
        # Perform inference on the frame
        frame_gray = cv2.cvtColor(frame, cv2.COLOR_RGB2GRAY)
        results = model(frame_gray, ch=1)
        frame_result = results[0].plot(img=frame)
        try:
            first_box = results[0].boxes[0]
            x1, y1, x2, y2 = first_box.xyxy[0]
            x1, y1, x2, y2 = map(int, [x1, y1, x2, y2])
            cropped_image = frame_gray[y1:y2, x1:x2]

        except Exception:
            cropped_image = frame_gray

        text4 = pytesseract.pytesseract.image_to_string(cropped_image, lang='7seg', config='--psm 6 --oem 3 -c tessedit_char_whitelist=.0123456789 -c tessedit_char_blacklist=abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ:')

        position = (10, 100)  # Bottom-left corner of the text
        font = cv2.FONT_HERSHEY_DUPLEX
        font_scale = 3
        thickness = 3

        # Annotate the frame with bounding boxes and labels
        annotated_frame = cv2.putText(frame_result, text4[:-1], position, font, font_scale, (0, 255, 0), thickness)

        # Display the annotated frame
        cv2.imshow('YOLO Live', annotated_frame)

        # Press 'q' to exit
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    else:
        break

# Release the capture object
cap.release()
cv2.destroyAllWindows()
